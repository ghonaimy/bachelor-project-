# %% [markdown]
# <a href="https://colab.research.google.com/github/ghonaimy/project-/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
plt.style.use('fivethirtyeight')
sns.set_style('whitegrid')

df = pd.read_csv(r'https://github.com/ghonaimy/Thesis/raw/main/Walmart%20(1)%20(1).csv')

#df = pd.read_csv(r'C:\Users\t-helghonaimy\Downloads\Walmart (1) (1).csv')

df.head()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-9-ccc5e253bb2c> in <cell line: 10>()
#       8 sns.set_style('whitegrid')
#       9
# ---> 10 df = pd.read_csv('https://github.com/ghonaimy/Thesis/raw/main/Walmart%20(1)%20(1).csv')
#      11
#      12 #df = pd.read_csv(r'C:\Users\t-helghonaimy\Downloads\Walmart (1) (1).csv')
#
# /usr/local/lib/python3.9/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
path='https://github.com/ghonaimy/Thesis/raw/main/Walmart%20(1)%20(1).csv'

tab= pd.read_csv(path)
tab
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-10-b8a60064770c> in <cell line: 3>()
#       1 path='https://github.com/ghonaimy/Thesis/raw/main/Walmart%20(1)%20(1).csv'
#       2
# ----> 3 tab= pd.read_csv(path)
#       4 tab
#
# /usr/local/lib/python3.9/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119 entries, 0 to 118
# ...
